# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Road.csv')

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Age_band_of_driver'], bins=30, edgecolor='black')
plt.xlabel('Age_band_of_driver')
plt.ylabel('Time')
plt.show()

# %%
sns.lineplot(x='Age_band_of_driver', y='Time',data=data)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
sns.violinplot(x='Road_surface_type', y='Road_surface_conditions', data=data)
plt.xlabel('Road_surface_type')
plt.ylabel('Road_surface_conditions')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y='Number_of_vehicles_involved', data=data)
plt.ylabel('Number_of_vehicles_involved')
plt.show()

# %%
plt.figure(figsize=((7, 6)))
sns.countplot(x='Age_band_of_driver', hue='Number_of_casualties', data=data)
plt.xlabel('Age_band_of_driver')
plt.ylabel('Number_of_casualties')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Age_band_of_driver', y='Number_of_vehicles_involved', hue='Day_of_week', data=data)
plt.xlabel('Age_band_of_driver')
plt.ylabel('Number_of_vehicles_involved')
plt.show()

# %%
sns.pairplot(data, hue='Age_band_of_driver')
plt.show()

# %%
plt.figure(figsize=((7, 6)))
sns.countplot(x='Driving_experience', hue='Vehicle_driver_relation', data=data)
plt.xlabel('Driving_experience')
plt.ylabel('Age_band_of_driver')
plt.show()

# %%
sns.violinplot(x='Day_of_week', y='Area_accident_occured', data=data)
plt.xlabel('Day_of_week')
plt.ylabel('Area_accident_occured')
plt.show()

# %%
sns.lineplot(x='Day_of_week', y='Area_accident_occured',data=data)
plt.xlabel('Day_of_week')
plt.ylabel('Area_accident_occured')
plt.show()
